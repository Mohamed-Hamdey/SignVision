# %%
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img

# Paths
original_dataset = "E:/Downloads/sign_language/SignVision/data_processed/crops/train"
augmented_dataset = "dataset_augmented"

# Recreate output folder cleanly
if os.path.exists(augmented_dataset):
    shutil.rmtree(augmented_dataset)
os.makedirs(augmented_dataset, exist_ok=True)

# Define augmentation generator
datagen = ImageDataGenerator(
    rotation_range=25,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.2,
    zoom_range=0.2,
    brightness_range=[0.6, 1.4],
    horizontal_flip=True,
    fill_mode='nearest'
)

# Number of augmented images to create per input image
AUGS_PER_IMAGE = 5

for class_name in sorted(os.listdir(original_dataset)):
    class_dir = os.path.join(original_dataset, class_name)
    if not os.path.isdir(class_dir):
        continue
    
    save_dir = os.path.join(augmented_dataset, class_name)
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"🔄 Augmenting class: {class_name}")
    
    for filename in os.listdir(class_dir):
        img_path = os.path.join(class_dir, filename)
        try:
            img = load_img(img_path)
            x = img_to_array(img)
            x = x.reshape((1,) + x.shape)

            # Generate augmented images
            i = 0
            for batch in datagen.flow(x, batch_size=1, save_to_dir=save_dir, save_prefix="aug", save_format="jpg"):
                i += 1
                if i >= AUGS_PER_IMAGE:
                    break  # Stop after N augmentations

            # Also copy the original image
            shutil.copy(img_path, os.path.join(save_dir, filename))
        except Exception as e:
            print(f"⚠️ Skipping {filename}: {e}")

print("\n✅ Augmentation completed successfully!")
# Out:
# 🔄 Augmenting class: 0
# 🔄 Augmenting class: 1
# 🔄 Augmenting class: 2
# 🔄 Augmenting class: 3
# 🔄 Augmenting class: 4
#
# ✅ Augmentation completed successfully!

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
import os

# Paths
train_dir = "dataset_augmented"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 25
NUM_CLASSES = 5  # 0–4

# Data generator
train_datagen = ImageDataGenerator(validation_split=0.2, rescale=1./255)
train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training"
)
val_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation"
)

# Model: MobileNetV2 base
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze base layers initially

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation="relu")(x)
output = Dense(NUM_CLASSES, activation="softmax")(x)
model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# Training
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS
)

# Unfreeze last layers and fine-tune
base_model.trainable = True
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

fine_tune_epochs = 10
history_finetune = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=fine_tune_epochs
)

# Save model
os.makedirs("models", exist_ok=True)
model.save("models/signvision_cnn_augmented.h5")
print("\n✅ Model training completed and saved to 'models/signvision_cnn_augmented.h5'")
# Out:
# Found 493 images belonging to 5 classes.
# Found 122 images belonging to 5 classes.
# c:\Users\PC\venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 677ms/step - accuracy: 0.1639 - loss: 1.9743 - val_accuracy: 0.4508 - val_loss: 1.3169
# Epoch 2/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 578ms/step - accuracy: 0.4407 - loss: 1.3768 - val_accuracy: 0.7541 - val_loss: 0.8866
# Epoch 3/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 600ms/step - accuracy: 0.6787 - loss: 0.9483 - val_accuracy: 0.9098 - val_loss: 0.6054
# Epoch 4/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 579ms/step - accuracy: 0.8143 - loss: 0.7399 - val_accuracy: 0.9344 - val_loss: 0.4245
# Epoch 5/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 596ms/step - accuracy: 0.8609 - loss: 0.5766 - val_accuracy: 0.9508 - val_loss: 0.3171
# Epoch 6/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 620ms/step - accuracy: 0.9234 - loss: 0.4202 - val_accuracy: 0.9590 - val_loss: 0.2405
# Epoch 7/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 572ms/step - accuracy: 0.9121 - loss: 0.3961 - val_accuracy: 0.9590 - val_loss: 0.1958
# Epoch 8/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 561ms/step - accuracy: 0.9348 - loss: 0.3131 - val_accuracy: 0.9672 - val_loss: 0.1720
# Epoch 9/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 568ms/step - accuracy: 0.9560 - loss: 0.2518 - val_accuracy: 0.9590 - val_loss: 0.1415
# Epoch 10/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 577ms/step - accuracy: 0.9712 - loss: 0.1994 - val_accuracy: 0.9672 - val_loss: 0.1287
# Epoch 11/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 581ms/step - accuracy: 0.9836 - loss: 0.1565 - val_accuracy: 0.9672 - val_loss: 0.1139
# Epoch 12/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 558ms/step - accuracy: 0.9814 - loss: 0.1500 - val_accuracy: 0.9672 - val_loss: 0.1051
# Epoch 13/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 637ms/step - accuracy: 0.9853 - loss: 0.1338 - val_accuracy: 0.9672 - val_loss: 0.0925
# Epoch 14/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 582ms/step - accuracy: 0.9748 - loss: 0.1384 - val_accuracy: 0.9672 - val_loss: 0.0885
# Epoch 15/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 668ms/step - accuracy: 0.9787 - loss: 0.1257 - val_accuracy: 0.9672 - val_loss: 0.0884
# Epoch 16/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9866 - loss: 0.0969 - val_accuracy: 0.9918 - val_loss: 0.0731
# Epoch 17/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9913 - loss: 0.0882 - val_accuracy: 0.9836 - val_loss: 0.0688
# Epoch 18/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9877 - loss: 0.0940 - val_accuracy: 0.9836 - val_loss: 0.0697
# Epoch 19/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9835 - loss: 0.0903 - val_accuracy: 0.9836 - val_loss: 0.0669
# Epoch 20/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9849 - loss: 0.0714 - val_accuracy: 0.9918 - val_loss: 0.0582
# Epoch 21/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9958 - loss: 0.0671 - val_accuracy: 0.9918 - val_loss: 0.0555
# Epoch 22/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9940 - loss: 0.0528 - val_accuracy: 0.9918 - val_loss: 0.0560
# Epoch 23/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9912 - loss: 0.0512 - val_accuracy: 0.9918 - val_loss: 0.0533
# Epoch 24/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 998ms/step - accuracy: 0.9887 - loss: 0.0588 - val_accuracy: 0.9918 - val_loss: 0.0551
# Epoch 25/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9976 - loss: 0.0538 - val_accuracy: 0.9918 - val_loss: 0.0466
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.5932 - loss: 1.0624 - val_accuracy: 0.9918 - val_loss: 0.0448
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7693 - loss: 0.6014 - val_accuracy: 0.9918 - val_loss: 0.0438
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8840 - loss: 0.3774 - val_accuracy: 0.9918 - val_loss: 0.0437
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9391 - loss: 0.2163 - val_accuracy: 0.9918 - val_loss: 0.0443
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9772 - loss: 0.1657 - val_accuracy: 0.9918 - val_loss: 0.0430
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9799 - loss: 0.1472 - val_accuracy: 0.9836 - val_loss: 0.0432
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9939 - loss: 0.1002 - val_accuracy: 0.9836 - val_loss: 0.0423
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9973 - loss: 0.0808 - val_accuracy: 0.9836 - val_loss: 0.0417
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9964 - loss: 0.0715 - val_accuracy: 0.9836 - val_loss: 0.0405
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9870 - loss: 0.0783 - val_accuracy: 0.9836 - val_loss: 0.0392
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model training completed and saved to 'models/signvision_cnn_augmented.h5'
